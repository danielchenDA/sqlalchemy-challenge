# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#database_path = "Resources/hawaii.sqlite"
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
##conn = engine.connect()

# %%
## Attempt to see what the table column headers are but failed. I can't seem to grasp why 
## I keep getting the error that the "hawaii" table does not exist.

#data = pd.read_sql("SELECT * FROM hawaii", conn)
#data.head()

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Display first row's data of Measurement table in dictionary format
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1892f94c438>,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'tobs': 65.0,
#  'date': '2010-01-01',
#  'id': 1}

# %%
# Display first row's data of Station table in dictionary format
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1892f94cfd0>,
#  'id': 1,
#  'elevation': 3.0,
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US',
#  'latitude': 21.2716,
#  'station': 'USC00519397'}

# %%
from sqlalchemy import inspect
# Create inspector
inspector = inspect(engine)

# %%
# Use inspector to grab table names
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Print column names and types for measurement table
columns = inspector.get_columns('measurement')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Print column names and types for station table
columns = inspector.get_columns('station')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
##last_12_precip_data = session.query(Measurement).filter()

# Calculate the date 1 year ago from the last data point in the database
last_row = session.query(Measurement).order_by(Measurement.date.desc()).first()
last_row.__dict__

## We want data points 2016-08-23 and onwards
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1892f960d30>,
#  'prcp': 0.0,
#  'station': 'USC00519397',
#  'tobs': 81.0,
#  'date': '2017-08-23',
#  'id': 2724}

# %%
# Perform a query to retrieve the date and precipitation scores
last_12_mo_data = session.query(Measurement.date, Measurement.prcp).\
                    filter(Measurement.date >= '2016-08-23').\
                    order_by(Measurement.date).all()
last_12_mo_data
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-23', 0.15),
#  ('2016-08-23', 0.05),
#  ('2016-08-23', None),
#  ('2016-08-23', 0.02),
#  ('2016-08-23', 1.79),
#  ('2016-08-23', 0.7),
#  ('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
last_12_mo_df = pd.DataFrame(last_12_mo_data)
last_12_mo_df = last_12_mo_df.set_index('date')

# Sort the dataframe by date
last_12_mo_df.sort_index(ascending=True,inplace=True)
last_12_mo_df.head(10)
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-23  0.15
# 2016-08-23  0.05
# 2016-08-23   NaN
# 2016-08-23  0.02
# 2016-08-23  1.79
# 2016-08-23  0.70
# 2016-08-24  0.08
# 2016-08-24  2.15
# 2016-08-24  2.28

# %%
# Use Pandas Plotting with Matplotlib to plot the data
fig, ax = plt.subplots()

x_data = last_12_mo_df.index.tolist()
y_data = last_12_mo_df['prcp'].tolist()
plt.plot(x_data, y_data, label="Precipitation")

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

plt.xlabel('Date')
plt.legend(loc='upper center')

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calculate the summary statistics for the precipitation data

last_12_mo_df.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?
count_of_stations = session.query(Station.station).count()
print(f"There are {count_of_stations} total stations available in this dataset.")
# Out:
# There are 9 total stations available in this dataset.

# %%
station = session.query(Station.name)
station

# %%
# Prints station table
sel = [Station.id,
       Station.name,
       Station.latitude,
       Station.longitude,
       Station.elevation]
stations = session.query(*sel)
for record in stations:
  (s_id, s_nm, s_lat, s_long, s_elev) = record
  print(f"{s_id}, {s_nm}, {s_lat}, {s_long}, {s_elev}")
# Out:
# 1, WAIKIKI 717.2, HI US, 21.2716, -157.8168, 3.0
# 2, KANEOHE 838.1, HI US, 21.4234, -157.8015, 14.6
# 3, KUALOA RANCH HEADQUARTERS 886.9, HI US, 21.5213, -157.8374, 7.0
# 4, PEARL CITY, HI US, 21.3934, -157.9751, 11.9
# 5, UPPER WAHIAWA 874.3, HI US, 21.4992, -158.0111, 306.6
# 6, WAIMANALO EXPERIMENTAL FARM, HI US, 21.33556, -157.71139, 19.5
# 7, WAIHEE 837.5, HI US, 21.45167, -157.84888999999998, 32.9
# 8, HONOLULU OBSERVATORY 702.2, HI US, 21.3152, -157.9992, 0.9
# 9, MANOA LYON ARBO 785.2, HI US, 21.3331, -157.8025, 152.4

# %%
# Check to see if both tables have the same stations
## Confirmed that at least 1 station is the same in both tables
session.query(Station.station, Measurement.station).limit(10).all()
# Out:
# [('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397'),
#  ('USC00519397', 'USC00519397')]

# %%
## What are the most active stations? (i.e. what stations have the most rows)?
## List the stations and the counts in descending order.
sel = [Station.id,
       Station.name,
       func.count(Station.station)]
most_active_stations = session.query(*sel).\
                    join(Measurement, Station.station == Measurement.station).\
                    group_by(Station.name).\
                    order_by(func.count(Station.name).desc()).limit(3).all()

print("The most active stations are: \n")
for record in most_active_stations:
    (s_id, s_nm, s_obs) = record
    print(f"{s_nm} with {s_obs} observations \n")
# Out:
# The most active stations are:
#
# WAIHEE 837.5, HI US with 2772 observations
#
# WAIKIKI 717.2, HI US with 2724 observations
#
# KANEOHE 838.1, HI US with 2709 observations

# %%
## List the stations and the counts in descending order.

obs_count_station = session.query(*sel).\
                join(Measurement, Station.station == Measurement.station).\
                group_by(Station.name).\
                order_by(func.count(Station.name).desc()).all()

obs_count_station
# Out:
# [(7, 'WAIHEE 837.5, HI US', 2772),
#  (1, 'WAIKIKI 717.2, HI US', 2724),
#  (2, 'KANEOHE 838.1, HI US', 2709),
#  (6, 'WAIMANALO EXPERIMENTAL FARM, HI US', 2669),
#  (9, 'MANOA LYON ARBO 785.2, HI US', 2612),
#  (3, 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 2202),
#  (8, 'HONOLULU OBSERVATORY 702.2, HI US', 1979),
#  (4, 'PEARL CITY, HI US', 1372),
#  (5, 'UPPER WAHIAWA 874.3, HI US', 511)]

# %%
## Station with the highest number of observations
max_obs = 0
max_nm = ""

for record in obs_count_station:
    (s_id, s_nm, s_obs) = record
    if s_obs > max_obs:
        max_obs = s_obs
        max_nm = s_nm
        
print(f'Station {max_nm} has the most number of observations with {max_obs}.')
# Out:
# Station WAIHEE 837.5, HI US has the most number of observations with 2772.

# %%
##### Excess code, please ignore
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
###active_station_dict = {}
###str(list_of_ints).strip('[]')
#for station in station_list:
#        reformatted_count = int(str(session.query(func.count(Measurement.station)).\
#                            filter(Measurement.station==station).all()).strip('[]').strip('()').strip(','))
#        active_station_dict[station] = reformatted_count
#active_station_dict

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
### Messy but had a hard time figuring out another way to do it, so I used .strip to take away certain symbols to get the format that I could print out cleanly
min_temp_7 = session.query(func.min(Measurement.tobs)).\
                filter(Station.id == 7).all()
min_temp_7 = int(np.ravel(min_temp_7))

max_temp_7 = session.query(func.max(Measurement.tobs)).\
                filter(Station.id == 7).all()
max_temp_7 = int(np.ravel(max_temp_7))

avg_temp_7 = session.query(func.avg(Measurement.tobs)).\
                filter(Station.id == 7).all()
avg_temp_7 = int(np.ravel(avg_temp_7))

print(f"The most active station recorded its lowest temperature at {min_temp_7} °F and its highest temperature at {max_temp_7} °F.")
print(f"The average temperature of all its observations is {avg_temp_7} °F.")
# Out:
# The most active station recorded its lowest temperature at 53 °F and its highest temperature at 87 °F.
# The average temperature of all its observations is 73 °F.

# %%
# Checks for null values in the tobs column: if 0, then it means the observation count is the same as the temperature observation count
check_null_temp = session.query(Measurement.station).\
                    filter(Measurement.tobs == "").count()
check_null_temp
# Out:
# 0

# %%
# Choose the station with the highest number of temperature observations.
## Station with highest number of temp obs: Station.id == 7 
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
## From earlier, we want data points 2016-08-23 and onwards, which gives us the last 12 months worth of data

last_12_mo_tobs_7 = session.query(Measurement.tobs).\
                        join(Station, Measurement.station == Station.station).\
                        filter(Measurement.date >= '2016-08-23').\
                        filter(Station.id == 7).\
                        order_by(Measurement.date).all()

# %%
last_12_mo_tobs_7_list = list(np.ravel(last_12_mo_tobs_7))

last_12_mo_tobs_7_list
# Out:
# [77.0,
#  77.0,
#  80.0,
#  80.0,
#  75.0,
#  73.0,
#  78.0,
#  77.0,
#  78.0,
#  80.0,
#  80.0,
#  78.0,
#  78.0,
#  78.0,
#  73.0,
#  74.0,
#  80.0,
#  79.0,
#  77.0,
#  80.0,
#  76.0,
#  79.0,
#  75.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  76.0,
#  74.0,
#  77.0,
#  78.0,
#  79.0,
#  79.0,
#  77.0,
#  80.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  75.0,
#  76.0,
#  73.0,
#  72.0,
#  71.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  77.0,
#  79.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  74.0,
#  75.0,
#  76.0,
#  73.0,
#  76.0,
#  74.0,
#  77.0,
#  76.0,
#  76.0,
#  74.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  71.0,
#  63.0,
#  70.0,
#  68.0,
#  67.0,
#  77.0,
#  74.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  76.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  75.0,
#  74.0,
#  75.0,
#  74.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  73.0,
#  74.0,
#  70.0,
#  72.0,
#  70.0,
#  67.0,
#  67.0,
#  69.0,
#  70.0,
#  68.0,
#  69.0,
#  69.0,
# ...

# %%
#Plot the results as a histogram with 12 bins
plt.hist(last_12_mo_tobs_7_list, bins = 12)
plt.xlabel("Temperature °F")
plt.ylabel("Number of Observations")
plt.title("Station 7: Last 12 Mo. of Temp. Observations")
plt.show()

# %%
1, WAIKIKI 717.2, HI US, 21.2716, -157.8168, 3.0
2, KANEOHE 838.1, HI US, 21.4234, -157.8015, 14.6
3, KUALOA RANCH HEADQUARTERS 886.9, HI US, 21.5213, -157.8374, 7.0
4, PEARL CITY, HI US, 21.3934, -157.9751, 11.9
5, UPPER WAHIAWA 874.3, HI US, 21.4992, -158.0111, 306.6
6, WAIMANALO EXPERIMENTAL FARM, HI US, 21.33556, -157.71139, 19.5
7, WAIHEE 837.5, HI US, 21.45167, -157.84888999999998, 32.9
8, HONOLULU OBSERVATORY 702.2, HI US, 21.3152, -157.9992, 0.9
9, MANOA LYON ARBO 785.2, HI US, 21.3331, -157.8025, 152.4

Station Columns:
id INTEGER
station TEXT
name TEXT
latitude FLOAT
longitude FLOAT
elevation FLOAT

Measurement Columns:
id INTEGER
station TEXT
date TEXT
prcp FLOAT
tobs FLOAT
# Out:
#   File "<ipython-input-35-e48f2dfcfac3>", line 1
#     1, WAIKIKI 717.2, HI US, 21.2716, -157.8168, 3.0
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
